# %%
import pickle
import pandas as pd
import numpy as np
import os

# %%
def predict_topics(location, model, vectorizer, source):
    df = pd.read_csv(location)
    if(source == 'Google'):
        # Retrieve only reviews column
        df = df['text']
        print(location.split('/')[-1])
    elif(source == 'Yelp'):
        df = df['review']
        print(location.split('/')[-1])

    # Change all empty strings to nan
    df.replace('', np.nan, inplace=True)
    # Remove all empty rows
    df.dropna(inplace=True)

    # Transform the reviews using vectorizer
    text = vectorizer.transform(df)
    # Transform text using model
    scores = model.transform(text)
    # Retrieve topics from model
    topics = pd.DataFrame(model.components_)
    # Change rows to Topic and number
    topics.index = ['Topic ' + str(i) for i in range(model.n_components)]

    # Get the text from words
    words = np.array(vectorizer.get_feature_names())
    topic_words = []
    # Go through values in each cluster
    for i in model.components_:
        # Inversing values and return indices of sorted 
        locs = (-i).argsort()
        # Add the elements from the array along the mentioned axis and indices
        topic_words.append(words.take(locs))

    # Convert list to df
    words_df = pd.DataFrame(topic_words)
    # Add Topic to each column
    words_df.index = ['Topic '+ str(i) for i in range(words_df.shape[0])]

    # Find the highest value and return the column's value
    topic = words_df.iloc[1:11, np.argmax(scores)].values.tolist()
    print(topic)
    return topic

# %%
# Location to loop through Yelp reviews
# Go to folder
def process_yelp(model, vectorizer):
    directory = "../../dataset/yelp/processed_reviews/"
    source = 'Yelp'
    for filename in os.listdir(directory):
        # Find all files that end with CSV
        if filename.endswith(".csv"):
            name = filename.replace("-hoboken_processed.csv", "")
            topics =  predict_topics(os.path.join(directory, filename), model, vectorizer, source)
            if name in restaurant_with_topics:
                restaurant_with_topics[name] = restaurant_with_topics[name] + topics
            else:
                restaurant_with_topics[name] = topics

# %%
# Location to loop through Google reviews
# Go to folder
def process_google(model, vectorizer):
    directory = "../../dataset/google/processed_reviews/"
    source = 'Google'
    for filename in os.listdir(directory):
        # Find all files that end with CSV
        if filename.endswith(".csv"):
            name = filename.replace("_processed.csv", "")
            topics =  predict_topics(os.path.join(directory, filename), model, vectorizer, source)
            if name in restaurant_with_topics:
                restaurant_with_topics[name] = restaurant_with_topics[name] + topics
            else:
                restaurant_with_topics[name] = topics

# %%
# Load Model and vectorizer
model = pickle.load(open('../../model/lda_model.sav', 'rb'))
vectorizer = pickle.load(open('../../model/lda_vectorizer.sav', 'rb'))
restaurant_with_topics = {}

# %%
# Used to create CSV to store topics
def write_into_csv(filename, header):
    # Process Google and Yelp Reviews
    process_google(model, vectorizer)
    process_yelp(model, vectorizer)
    rest_list = []
    for restaurant, topics in restaurant_with_topics.items():
        rest_list.append([restaurant, ",".join(topics)])

    with open(filename + ".csv", 'w', encoding='UTF8') as f:
        # Create header
        f.write(header)
        f.write('\n')
        # Add topics
        for name in rest_list:
            f.write("|".join(name))
            f.write('\n')

write_into_csv("../../dataset/restaurant_with_topics_lda", "name,topics")
# Out:
# 7-stars-pizzeria_processed.csv
# ['visiting', 'tot', 'limited', 'wine', 'hungry', 'matter', 'barely', 'rather', 'easily']
# 80-river-bar-kitchen_processed.csv
# ['enjoy', 'since', 'protein', 'seated', 'ca', 'said', 'perfect', 'even', 'next']
# 8th-street-tavern_processed.csv
# ['extremely', 'overcooked', 'husband', 'try', 'yes', 'love', 'full', 'sausage', 'disappointed']
# acai-ya-later_processed.csv
# ['fall', 'undercooked', 'syrup', 'shocked', 'absolutely', 'code', 'least', 'honey', 'smaller']
# acme-markets_processed.csv
# ['immediately', '4th', 'tabouleh', 'drinking', 'body', 'dancing', 'bonito', 'man', 'frank']
# alessio-s-cafe-gelato-pizza_processed.csv
# ['ok', 'might', 'black', 'kept', 'joint', 'ask', 'world', 'snack', 'salt']
# ali-baba-restaurant_processed.csv
# ['twice', 'note', 'expecting', 'case', 'word', 'indoors', 'combination', 'art', 'churrasco']
# amanda-bananas_processed.csv
# ['crowd', 'portion', 'come', 'min', 'old', 'experience', 'flavor', 'croissant', 'server']
# amanda-s_processed.csv
# ['pleaser', 'passed', 'wound', 'quote', 'chose', 'applied', 'overwhelmingly', '1pm', 'feed']
# anthony-david-s_processed.csv
# ['bartender', 'get', 'taste', 'one', 'better', 'could', 'pepper', 'cheese', 'menu']
# apulia_processed.csv
# ['twice', 'note', 'expecting', 'case', 'word', 'indoors', 'combination', 'art', 'churrasco']
# arthur-s-hoboken_processed.csv
# ['margarita', 'ribeye', 'half', 'line', 'extra', 'tv', 'grilled', 'choose', 'rib']
# asia-sushi-chinese_processed.csv
# ['must', 'dino', 'canai', 'lady', 'keep', 'soul', 'item', 'bite', 'soon']
# augustino-s_processed.csv
# ['glass', 'amount', 'shaka', 'done', 'everything', 'free', 'enough', 'clean', 'looking']
# ayame-hibachi-sushi_processed.csv
# ['absolute', 'relatively', 'brand', 'buck', 'frank', 'popular', 'molto', 'soda', 'month']
# baja_processed.csv
# ['frequently', 'cobbler', 'chopstick', 'greeting', 'blown', 'design', 'smelly', 'tough', 'lived']
# bangkok-city-thai_processed.csv
# ['review', 'mine', 'dollar', 'industry', 'traditional', 'cup', 'steamed', 'elysian', 'alla']
# barbes_processed.csv
# ['enjoy', 'since', 'protein', 'seated', 'ca', 'said', 'perfect', 'even', 'next']
# bareburger_processed.csv
# ['lot', 'decent', 'nice', 'made', 'home', 'lot', 'well', 'cream', 'meat']
# belo-bar_processed.csv
# ['celebration', 'rather', 'nut', 'dirty', 'changed', 'cramped', 'honestly', 'prepared', 'smoked']
# ben-jerrys_processed.csv
# ['jack', 'reheated', 'parsley', 'cell', 'oreo', 'closed', 'quesadillix', 'bummed', 'unusual']
# benny-tudino-s_processed.csv
# ['tricky', 'slap', 'weighed', 'headache', 'chewier', 'sucked', 'suspicious', 'cashier', 'closed']
# bk-lobster-hoboken_processed.csv
# ['super', 'brisket', 'delivery', 'bill', 'something', 'find', 'review', 'cold', 'started']
# black-rail-coffee_processed.csv
# ['rap', 'palm', 'addicting', 'advise', 'folded', 'witnessed', 'fin', 'ideal', 'read']
# blue-eyes-restaurant_processed.csv
# ['ability', 'control', 'till', 'buying', 'skill', 'gon', 'cafeteria', 'peaceful', 'loaded']
# bluestone-lane-hoboken-cafe_processed.csv
# ['michael', 'sprout', 'tangy', 'surprise', 'watched', 'machine', 'limited', 'beet', 'near']
# bwe-kafe_processed.csv
# ['spelled', 'returned', 'feng', 'hoped', 'entrance', 'complex', 'korea', 'barely', 'city']
# cafe-michelina_processed.csv
# ['enough', 'around', 'sure', 'felt', 'work', 'needed', 'back', 'still', 'gnocchi']
# cafe-vista_processed.csv
# ['anything', 'fatty', 'kung', 'showed', 'three', 'le', 'messy', 'slow', 'recommendation']
# carlo-s-bakery_processed.csv
# ['breeze', '21', 'biggest', 'welcomed', 'ol', 'sad', 'parked', 'dd', 'ready']
# carpe-diem_processed.csv
# ['occasion', 'needed', 'tapioca', 'receipt', 'okay', 'allowed', 'closed', 'greek', 'thin']
# chango-kitchen_processed.csv
# ['street', 'hot', 'star', 'many', 'another', 'wearing', 'two', 'next', 'another']
# charrito-s-midtown_processed.csv
# ['glass', 'amount', 'shaka', 'done', 'everything', 'free', 'enough', 'clean', 'looking']
# chicken-factory_processed.csv
# ['dance', 'husband', 'however', 'believe', 'hope', 'unfortunately', 'tough', 'unlimited', 'forward']
# chipotle-mexican-grill_processed.csv
# ['might', 'la', 'warm', 'expected', 'chicken', 'simply', 'vindaloo', '09', 'ice']
# choc-o-pain-french-bakery-and-cafe_processed.csv
# ['fair', 'drowned', 'walking', 'step', 'lunch', 'setting', 'exact', 'gelato', 'suggest']
# city-bistro_processed.csv
# ['town', 'regular', 'container', 'bring', 'came', 'liked', 'far', 'muffin', 'bite']
# cork-city-pub_processed.csv
# ['booked', 'vinegar', 'replaced', 'happening', 'cooked', 'poorly', 'familiar', 'moving', 'care']
# court-street_processed.csv
# ['overlooking', 'lost', 'layer', 'hospitality', 'including', 'yikes', 'country', 'awhile', 'supposed']
# cucina-saporito_processed.csv
# ['date', 'taste', 'vegan', 'call', 'lot', 'seemed', 'ever', 'cup', 'experience']
# curry-up-now_processed.csv
# ['entree', 'edamame', 'top', 'location', 'hour', 'hear', 'pick', 'found', 'although']
# d-s-soul-full-cafe_processed.csv
# ['left', 'spare', 'sometimes', 'burnt', 'gooey', 'capacity', 'pricey', 'traditional', 'satisfied']
# del-frisco-s-grille_processed.csv
# ['ability', 'control', 'till', 'buying', 'skill', 'gon', 'cafeteria', 'peaceful', 'loaded']
# delite-liquor-store_processed.csv
# ['craft', 'kind', 'mixed', 'end', 'nyc', 'sunday', 'long', 'today', 'water']
# dining-room-at-anthony-david-s_processed.csv
# ['back', 'really', 'ordered', 'ordered', 'cheese', 'really', 'fresh', 'get', 'came']
# dino-harry-s-steak-house_processed.csv
# ['expect', 'smoked', 'cup', 'pretty', 'everyone', 'gave', 'feel', 'everyone', 'incredible']
# dom-s-bakery-grand_processed.csv
# ['meal', '10', 'butter', 'least', 'town', 'covid', 'en', 'pancake', 'taste']
# dozzino_processed.csv
# ['pier', 'kinda', 'chain', 'based', 'insomnia', 'allow', 'perfectly', 'sugar', 'con']
# dunkin_processed.csv
# ['greeted', 'weak', 'bought', 'plenty', 'dom', 'dine', 'pig', 'fill', '19']
# east-la_processed.csv
# ['soon', 'seemed', 'chocolate', 'different', 'without', 'tried', 'quickly', 'yet', 'dip']
# eco-hoboken_processed.csv
# ['really', 'lunch', 'sauce', 'customer', 'bakery', 'get', 'ordered', 'little', 'meal']
# elysian-cafe_processed.csv
# ['cute', 'overpriced', 'thought', 'look', 'trip', 'wo', 'last', 'hash', 'said']
# empanadas-cafe_processed.csv
# ['bang', 'batman', 'charging', 'dead', 'flavoring', 'exchange', 'riot', 'energy', 'passion']
# empyrean-indian-kitchen-bar_processed.csv
# ['pretty', 'fresh', 'tried', 'waitress', 'also', 'around', 'try', 'seating', 'try']
# finnegan-s-pub_processed.csv
# ['usual', 'odd', '13', 'throw', 'pier', 'smaller', 'leftover', 'bombay', 'zucchini']
# fiore-s-house-of-quality_processed.csv
# ['top', 'crab', 'though', 'issue', 'away', 'made', 'parm', 'fry', 'olive']
# flatbread-grill_processed.csv
# ['wing', 'steakhouse', 'frozen', 'put', 'great', 'dog', 'cheesesteak', 'bloody', 'recommend']
# gfg-cafe-cuisine_processed.csv
# ['best', 'service', 'broth', 'staff', 'worth', 'group', 'little', 'benedict', 'loved']
# gogi-grill_processed.csv
# ['relax', 'honest', 'health', 'piece', 'husband', 'split', 'bonchon', 'incredibly', 'everyone']
# grand-vin_processed.csv
# ['much', 'worth', 'new', 'better', 'next', 'large', 'cutlet', 'stop', 'clam']
# greektown_processed.csv
# ['buzz', 'belly', 'replace', 'shady', 'min', 'patio', 'whether', 'growing', '17']
# green-garden_processed.csv
# ['highly', 'deal', 'honey', 'open', 'bought', 'crowd', 'might', 'baked', 'creamy']
# green-pear-cafe_processed.csv
# ['thursday', 'corn', 'authentic', 'pick', 'bread', 'cool', 'tender', 'salmon', 'share']
# green-rock-tap-grill_processed.csv
# ['19', 'anyone', 'signature', 'account', 'team', 'barbecue', 'case', 'app', 'rubbery']
# grimaldi-s-pizzeria_processed.csv
# ['off', 'english', 'killer', 'expressed', 'er', 'nobody', 'contained', 'coast', 'fire']
# h-s-giovanni-s-restaurant-pizzeria_processed.csv
# ['feature', 'main', '100', 'decide', 'crunch', 'messy', 'freaking', 'wi', 'tad']
# halifax_processed.csv
# ['concert', '48oz', 'suggested', 'clueless', 'set', 'activity', 'bloomfield', 'wanting', 'wished']
# hidden-grounds-coffee_processed.csv
# ['ordered', 'cajun', 'regular', 'experienced', 'yeah', 'boyfriend', 'spiced', 'prefer', 'addition']
# hoboken-burrito_processed.csv
# ['upscale', 'buck', 'cute', 'lack', 'front', 'barely', 'found', 'station', 'high']
# hoboken-catering_processed.csv
# ['everyone', 'dressing', 'tofu', 'really', 'nice', 'seated', 'even', 'came', 'enough']
# hoboken-waterfront_processed.csv
# ['area', 'shrimp', 'time', 'two', 'little', 'two', 'garlic', 'make', 'friend']
# honeygrow_processed.csv
# ['okay', 'exactly', 'mr', 'happen', 'course', 'saying', 'noodle', 'convenient', 'brussel']
# house-of-que_processed.csv
# ['never', 'wanted', 'street', 'thought', 'overpriced', 'expect', 'average', 'solid', 'room']
# hudson-river-waterfront-walkway_processed.csv
# ['chilled', 'yeah', 'foam', 'lacking', 'honor', 'fear', 'regardless', 'likely', 'indoor']
# hudson-table-hoboken_processed.csv
# ['old', 'actually', 'ginger', 'wo', 'dessert', 'small', 'cash', 'table', 'sat']
# il-tavolo-di-palmisano_processed.csv
# ['list', 'japanese', 'pineapple', 'understand', 'enough', 'take', 'biryani', 'large', 'prosciutto']
# illuzion_processed.csv
# ['way', 'going', 'filling', 'already', 'eating', 'dirty', 'whole', 'warm', 'ravioli']
# imposto-s-pizza_processed.csv
# ['repeat', 'bark', 'scrumptious', 'overcharge', 'comment', 'power', 'bombay', 'hibiscus', 'mild']
# insomnia-cookies_processed.csv
# ['irish', 'week', 'pick', 'disappointing', 'week', 'baby', 'another', 'water', 'highly']
# iron-monkey_processed.csv
# ['interior', 'stuffed', 'homemade', 'ticket', 'certainly', 'dream', 'husband', 'ridge', 'hint']
# jeffersons-coffee_processed.csv
# ['fan', 'ring', 'trying', 'extra', 'wing', 'server', 'see', '10', 'house']
# johnny-pepperoni_processed.csv
# ['older', 'drop', 'picture', 'professional', 'saving', 'write', 'melted', 'woman', 'law']
# jp-s-bagel-express_processed.csv
# ['fair', 'drowned', 'walking', 'step', 'lunch', 'setting', 'exact', 'gelato', 'suggest']
# karma-kafe_processed.csv
# ['helmer', 'drank', 'finished', 'bos', 'heavier', 'friggin', 'universe', 'brownie', 'glove']
# keming_processed.csv
# ['great', 'roll', 'bowl', 'food', 'pizza', 'burger', 'sandwich', 'coffee', 'dish']
# kolo-klub_processed.csv
# ['manhattan', 'teriyaki', 'enjoy', 'guess', 'vanilla', 'order', 'lo', 'choc', 'kitchen']
# kung-fu-tea_processed.csv
# ['celebrate', 'smaller', 'lol', 'returned', 'check', 'medium', 'pesto', 'although', 'old']
# la-bouche_processed.csv
# ['plate', 'pay', 'pitaya', 'yes', 'eaten', 'napkin', 'standard', 'week', 'hummus']
# la-casa_processed.csv
# ['started', 'sirloin', 'wrong', 'upon', 'read', 'sister', 'tip', 'turning', 'chose']
# lisa-s-italian-deli-caterer_processed.csv
# ['nice', 'like', 'food', 'place', 'hoboken', 'one', 'google', 'sandwich', 'good']
# little-market_processed.csv
# ['fantastic', 'maybe', 'asian', 'much', 'life', 'black', 'eating', 'space', 'star']
# lo-fatt-chow_processed.csv
# ['pretty', 'fresh', 'tried', 'waitress', 'also', 'around', 'try', 'seating', 'try']
# losurdo-s-italian-deli-bread-bakery_processed.csv
# ['wicked', 'arrived', 'forward', 'although', 'lady', 'cooked', 'share', 'cheap', 'beautifully']
# m-p-biancamano_processed.csv
# ['7pm', 'complain', 'bomb', 'lie', 'macaroon', '10th', 'speaking', 'overpriced', 'vegetarian']
# malibu-diner_processed.csv
# ['tonic', 'called', 'bike', 'frustration', 'observation', 'socially', 'sadly', 'difference', 'kefta']
# mamoun-s-falafel-hoboken-nj_processed.csv
# ['skeptical', 'former', 'closest', 'cousin', 'cute', 'hundred', 'due', 'willing', 'comfort']
# margherita-s_processed.csv
# ['4th', 'mid', 'up', 'fed', 'nicer', 'redeem', 'blah', 'crumble', 'sample']
# mario-s_processed.csv
# ['zacks', 'guy', 'nugget', 'idiot', 'likely', 'st', 'given', 'checking', 'sundae']
# midtown-philly-steaks_processed.csv
# ['35', 'clearly', 'located', 'previously', 'maintained', 'summer', 'pretend', 'nitro', 'possible']
# monroe-s_processed.csv
# ['several', 'unfortunately', 'ate', 'turn', 'anywhere', 'disappointing', 'rico', 'bellini', 'overly']
# moran-s-pub_processed.csv
# ['weekly', 'word', 'tamarind', 'corner', 'slide', 'blast', 'freshly', 'highlight', 'rave']
# mr-wrap-s_processed.csv
# ['felt', 'long', 'tortilla', 'ahead', 'end', 'far', 'bland', '2017', 'mouth']
# muteki-ramen_processed.csv
# ['cheer', 'bass', 'fill', 'occasion', 'covered', 'health', 'offer', 'crazy', 'tough']
# napoli-s-pizza_processed.csv
# ['collection', 'already', 'pale', 'bothering', 'macadamia', 'figuring', 'doggy', 'warned', 'cracker']
# no-1_processed.csv
# ['walk', 'part', 'review', 'mediocre', 'le', 'visit', 'oh', 'quickly', 'bolognese']
# okinawa-sushi-grill_processed.csv
# ['noisy', 'drink', 'bottom', 'sad', 'classic', 'told', 'liked', 'quiet', 'vieja']
# old-german-bakery_processed.csv
# ['nick', 'underwhelmed', 'substituted', 'wallet', 'according', 'shelf', 'trick', 'homey', 'cheek']
# olivia-s_processed.csv
# ['work', 'choice', 'smoothie', 'awful', 'baked', 'mean', 'authentic', 'espresso', 'way']
# one12_processed.csv
# ['great', 'roll', 'bowl', 'food', 'pizza', 'burger', 'sandwich', 'coffee', 'dish']
# onieal-s_processed.csv
# ['fine', 'hour', 'point', 'walking', 'sold', 'upstairs', 'normally', 'opening', 'cherry']
# orale-mexican-kitchen_processed.csv
# ['back', 'really', 'ordered', 'ordered', 'cheese', 'really', 'fresh', 'get', 'came']
# panello_processed.csv
# ['pleasantly', 'larger', 'malaysia', 'assuming', 'table', 'crammed', 'tamarind', 'saw', 'aioli']
# panera-bread_processed.csv
# ['including', 'found', 'mine', 'excited', 'knew', 'entrance', 'stand', 'seem', 'bar']
# pastrami-house-delicatessen_processed.csv
# ['lounge', 'today', 'yet', 'returning', 'outside', 'bartender', 'local', 'block', 'especially']
# pho-nomenon_processed.csv
# ['wednesday', 'anything', 'added', 'dinner', 'cold', 'eating', 'stick', 'stopped', 'think']
# phoenix-bar-grill_processed.csv
# ['awesome', 'cooked', 'go', 'server', 'got', 'room', 'la', 'staff', 'nice']
# piccolos-cheesesteaks_processed.csv
# ['time', 'would', 'also', 'asked', 'time', 'drink', 'italian', 'hoboken', 'appetizer']
# pico-taco_processed.csv
# ['romantic', 'mostly', 'tonkotsu', 'decent', 'unfortunately', 'play', 'thinking', 'uptown', 'unique']
# pier-13-hoboken_processed.csv
# ['tell', 'questionable', 'grapefruit', 'changing', 'hear', 'worried', 'sister', 'canadian', 'component']
# piki-poke-hawaiian-poke-bowl_processed.csv
# ['unlimited', 'atmosphere', 'jerry', 'quite', 'update', 'towards', 'slab', 'pay', 'spectacular']
# pilsener-haus-biergarten_processed.csv
# ['knowledgeable', 'weird', 'thai', 'enough', 'getting', 'wall', 'absolutely', '2018', 'ended']
# pizzeria-hoboken_processed.csv
# ['watch', 'lot', 'give', 'meal', 'always', 'ok', 'give', 'line', 'grilled']
# playa-bowls_processed.csv
# ['happy', 'time', 'option', 'got', 'back', 'also', 'hot', 'french', 'cheese']
# prato-bakery_processed.csv
# ['bistro', 'almost', 'precious', 'calling', 'amount', 'block', 'stale', 'fantastic', 'green']
# precious-chinese-japanese-cuisine_processed.csv
# ['5pm', 'coke', 'none', 'essentially', 'cant', 'appreciated', 'kitchen', 'sounded', 'requested']
# proven-poke-co-hoboken_processed.csv
# ['menu', 'salmon', 'get', 'called', 'even', 'little', 'sub', 'got', 'like']
# qdoba-mexican-eats_processed.csv
# ['town', 'regular', 'container', 'bring', 'came', 'liked', 'far', 'muffin', 'bite']
# quality-greens-kitchen_processed.csv
# ['tends', 'mall', 'over', 'broken', 'cart', 'date', 'noticeable', '29', 'apart']
# rice-shop_processed.csv
# ['glass', 'amount', 'shaka', 'done', 'everything', 'free', 'enough', 'clean', 'looking']
# robongi-hoboken_processed.csv
# ['ta', '27', 'chai', 'happily', 'boxed', 'honest', 'mexicana', 'worthy', 'number']
# rosario-s-at-willow_processed.csv
# ['option', 'spring', 'brown', 'week', 'real', 'open', 'since', 'never', 'spicy']
# rosticeria-da-gigi_processed.csv
# ['drink', 'ordered', 'rice', 'minute', 'like', 'place', 'mozzarella', 'bagel', 'chicken']
# saku-hoboken_processed.csv
# ['felt', 'long', 'tortilla', 'ahead', 'end', 'far', 'bland', '2017', 'mouth']
# san-giuseppe_processed.csv
# ['mean', '18', 'seasoning', 'forgotten', 'germany', 'expectation', 'worst', 'year', 'suggested']
# sangria-hoboken_processed.csv
# ['back', 'really', 'ordered', 'ordered', 'cheese', 'really', 'fresh', 'get', 'came']
# satay_processed.csv
# ['picture', 'group', 'across', 'helped', 'foot', 'knew', 'charge', 'note', 'dad']
# seven-valleys_processed.csv
# ['absolutely', 'box', 'mint', 'started', 'inside', 'plenty', 'sliced', 'tasted', 'outdoor']
# shaka-bowl_processed.csv
# ['2am', 'tax', 'carbs', 'bug', 'weird', 'mid', 'disappointment', 'ricotta', 'aside']
# shake-shack_processed.csv
# ['buy', '32', 'discovered', 'initial', 'received', 'sunny', 'completely', 'reminds', 'picked']
# shokudo_processed.csv
# ['nacho', 'mignon', 'looking', 'outside', 'thank', 'change', 'falafel', 'fruit', 'week']
# shoprite-of-hoboken_processed.csv
# ['wednesday', 'anything', 'added', 'dinner', 'cold', 'eating', 'stick', 'stopped', 'think']
# sirenetta-seafood-raw-bar_processed.csv
# ['much', 'worth', 'new', 'better', 'next', 'large', 'cutlet', 'stop', 'clam']
# sorellina_processed.csv
# ['outstanding', 'plain', 'grill', 'talk', 'save', 'cheap', 'chat', 'veggie', 'linguine']
# south-lions-dim-sum-tea_processed.csv
# ['price', 'probably', 'first', 'since', 'nothing', 'decided', 'saturday', 'side', 'stuffed']
# south-street-fish-ramen-co_processed.csv
# ['remember', 'real', 'fu', 'boyfriend', 'expected', 'everywhere', 'remember', 'plain', 'recommended']
# souzafit-restaurant-hoboken_processed.csv
# ['highly', 'deal', 'honey', 'open', 'bought', 'crowd', 'might', 'baked', 'creamy']
# sri-thai_processed.csv
# ['dont', 'awhile', 'ago', 'middle', 'covid', 'dim', 'bet', 'upon', 'coconut']
# stingray-lounge_processed.csv
# ['nicely', 'afternoon', 'guy', 'machine', 'sandy', 'outdoors', 'ago', 'welcome', 'owner']
# subway_processed.csv
# ['must', 'dino', 'canai', 'lady', 'keep', 'soul', 'item', 'bite', 'soon']
# sushi-lounge_processed.csv
# ['pinot', 'swap', 'blender', 'worry', 'sh', 'skin', 'abundance', 'patient', 'sorbet']
# sweet_processed.csv
# ['see', 'let', 'meal', 'entire', 'local', 'end', 'something', 'visit', 'perfection']
# taqueria-hoboken_processed.csv
# ['drink', 'ordered', 'rice', 'minute', 'like', 'place', 'mozzarella', 'bagel', 'chicken']
# tastee-platters_processed.csv
# ['everyone', 'dressing', 'tofu', 'really', 'nice', 'seated', 'even', 'came', 'enough']
# tenth-street-pasta-pizza_processed.csv
# ['4th', 'mid', 'up', 'fed', 'nicer', 'redeem', 'blah', 'crumble', 'sample']
# the-ainsworth-hoboken_processed.csv
# ['shared', 'set', 'meh', 'taco', 'waste', 'longer', 'rabe', 'folk', 'brick']
# the-ale-house_processed.csv
# ['crowd', 'portion', 'come', 'min', 'old', 'experience', 'flavor', 'croissant', 'server']
# the-brass-rail_processed.csv
# ['rail', 'cobb', 'similar', 'gotten', 'mama', 'entire', 'mamouns', 'walking', 'wow']
# the-brick_processed.csv
# ['15', 'brought', 'rangoon', 'specifically', 'impressed', 'mom', 'update', 'including', 'forgot']
# the-cuban-restaurant-and-bar_processed.csv
# ['marie', 'example', 'questionable', 'pointing', 'bummed', 'liquid', 'mom', 'aka', 'actual']
# the-little-grocery_processed.csv
# ['casual', 'pricey', '10', 'served', 'door', 'hand', 'kind', 'store', 'arugula']
# the-madison-bar-grill_processed.csv
# ['others', 'casual', 'edamame', 'foot', 'dude', 'anymore', 'future', 'covered', 'quinoa']
# the-shannon_processed.csv
# ['hear', 'mouth', 'felt', 'disgusting', 'friend', 'walking', 'son', 'bad', 'nicely']
# the-stewed-cow_processed.csv
# ['fantastic', 'maybe', 'asian', 'much', 'life', 'black', 'eating', 'space', 'star']
# tony-boloney-s-hoboken_processed.csv
# ['sell', 'parent', 'carbonated', 'deserving', 'delivering', 'ugly', 'specialize', 'stevens', 'brandy']
# torna-pizzeria_processed.csv
# ['certain', 'bar', 'whatever', 'willing', 'change', 'impressive', 'award', 'despite', '20']
# tosti_processed.csv
# ['tonight', 'certainly', 'sadly', 'disrespectful', 'completely', 'eaten', 'fat', 'heart', 'available']
# touch-the-heart_processed.csv
# ['bit', 'appetizer', 'banana', 'night', 'find', 'packed', 'probably', 'ca', 'excellent']
# trader-joe-s_processed.csv
# ['delish', 'hope', 'presentation', 'forward', 'called', 'excited', 'tasteless', 'cut', 'serve']
# turning-point_processed.csv
# ['dinning', 'describe', 'walnut', '2019', 'fyi', 'willing', 'do', 'kafe', 'photo']
# ubu_processed.csv
# ['madison', 'seem', 'kick', 'note', 'crazy', 'loved', 'hoagie', 'move', 'phenomenal']
# uptown-pizzeria_processed.csv
# ['watching', 'fan', 'used', 'hope', 'excited', 'part', 'flavorful', 'rail', 'decor']
# urban-coalhouse-pizza-bar_processed.csv
# ['alex', 'couldnt', 'gyoza', 'bought', 'lame', 'madison', 'appeared', 'share', 'pine']
# vito-s-deli_processed.csv
# ['class', 'wow', 'peach', 'meanwhile', 'tuesday', 'certain', 'sopressata', 'become', 'watermelon']
# wicked-wolf-tavern_processed.csv
# ['brunch', 'well', 'fresh', 'manager', 'review', 'restaurant', 'vito', 'latte', 'great']
# wine-dad-s_processed.csv
# ['look', 'chef', 'satay', 'woman', '50', 'bbq', 'pita', 'size', 'take']
# wings-to-go-grande-pizza_processed.csv
# ['week', 'something', 'yogurt', 'second', 'long', 'asked', 'ham', 'different', 'still']
# yeung-ii_processed.csv
# ['casual', 'pricey', '10', 'served', 'door', 'hand', 'kind', 'store', 'arugula']
# zack-s_processed.csv
# ['outdoor', 'bbq', 'beef', 'horrible', 'give', 'went', 'amazing', 'right', 'parm']
# zero-otto-uno-cafe_processed.csv
# ['restaurant', 'big', 'extra', 'pay', 'tasted', 'big', 'oil', 'donut', 'white']
# 10th-and-willow-bar-and-grill-hoboken_processed.csv
# ['soccer', 'cheeseburger', 'almond', 'nice', 'rating', 'yelp', 'although', 'extra', 'despite']
# 16-handles-hoboken_processed.csv
# ['filled', 'someone', 'powder', 'advance', 'par', 'attention', 'man', 'piece', 'ingredient']
# acai-ya-later-hoboken_processed.csv
# ['specialty', 'finger', 'future', 'lose', 'matter', 'pleasantly', 'north', 'fall', 'buttery']
# ainsworth-hoboken-hoboken_processed.csv
# ['wheel', 'hash', 'phenomenal', 'spoken', 'kit', 'wooden', 'ginormous', 'write', 'appealing']
# alessios-cafe-gelato-pizza-hoboken_processed.csv
# ['unless', 'check', 'legit', 'doubt', 'center', 'control', 'yesterday', 'smile', 'frisco']
# alfalfa-hoboken_processed.csv
# ['thing', 'expect', 'know', 'late', 'show', 'especially', 'gyro', 'juice', 'something']
# ali-baba-hoboken-2_processed.csv
# ['yankee', 'decoration', 'maple', 'delivering', 'plate', 'accommodating', 'meaning', 'greece', 'signature']
# amanda-bananas-hoboken_processed.csv
# ['dog', 'totally', 'store', 'honestly', 'cheap', 'heard', 'gave', 'classic', 'long']
# amandas-restaurant-hoboken-2_processed.csv
# ['silent', 'friggin', 'basis', 'frown', 'danielle', 'lax', 'bitty', 'softer', 'napkin']
# anthony-davids-hoboken_processed.csv
# ['stress', 'promptly', 'relish', 'thru', 'professional', 'elbow', 'cheapest', 'regardless', 'sauvignon']
# antique-bar-and-bakery-hoboken-2_processed.csv
# ['comedy', 'benefit', 'executed', 'claiming', '4am', 'casually', 'puedes', '23', 'remaining']
# apulia-hoboken_processed.csv
# ['parent', 'please', 'inn', 'general', 'window', 'ate', 'encanta', 'display', 'chunk']
# arthurs-steaks-hoboken_processed.csv
# ['amanda', 'option', 'steamed', 'making', 'italian', 'ca', 'chaat', 'packed', 'chocolate']
# augustinos-hoboken_processed.csv
# ['word', 'disappoint', 'charge', 'desert', 'consistency', 'fourth', 'surprised', 'damn', 'bird']
# ayame-hibachi-and-sushi-hoboken_processed.csv
# ['12', 'course', 'non', 'together', 'wife', 'drunk', 'forget', 'lemon', 'used']
# baking-mama-hoboken_processed.csv
# ['jazz', 'goodness', '11', 'turning', 'nutella', 'mention', 'house', 'warmer', 'hour']
# bangkok-city-thai-restaurant-hoboken_processed.csv
# ['tender', '11', 'served', 'recommend', 'man', 'impossible', 'miss', 'banana', 'soft']
# barbès-restaurant-hoboken_processed.csv
# ['belly', 'skewer', 'candy', 'held', 'array', 'assuming', 'melting', 'reviewing', '21']
# bareburger-hoboken-hoboken_processed.csv
# ['seating', 'eat', 'well', 'last', 'never', 'menu', 'prosciutto', 'wait', 'calamari']
# basiles-pizza-hoboken_processed.csv
# ['stranger', '1pm', 'mofogo', 'sell', 'contest', 'specific', 'return', 'cheerful', 'grigio']
# bean-vault-coffee-hoboken_processed.csv
# ['distance', 'nicely', 'cashier', 'reply', 'important', 'aside', 'pure', 'yesterday', 'easy']
# belo-bar-hoboken_processed.csv
# ['believe', 'container', 'smooth', 'security', 'service', 'section', 'competition', 'kid', 'fell']
# ben-and-jerry-s-hoboken_processed.csv
# ['street', 'hot', 'star', 'many', 'another', 'wearing', 'two', 'next', 'another']
# benny-tudinos-pizzeria-hoboken_processed.csv
# ['guess', 'ware', 'glutinous', '07', 'written', 'chased', 'netflix', 'settled', 'robust']
# bin-14-hoboken_processed.csv
# ['fare', 'added', 'reason', 'dropped', 'basically', 'cover', 'soooo', 'press', 'getting']
# black-bear-bar-and-grill-hoboken_processed.csv
# ['shepard', 'luckily', 'shaved', 'inquire', 'tin', 'zero', 'excited', 'longer', 'beverage']
# black-rail-coffee-hoboken_processed.csv
# ['recently', 'add', 'oil', 'send', 'left', 'fan', 'gigi', 'keep', 'filled']
# blue-eyes-restaurant-hoboken_processed.csv
# ['ideal', 'thinly', 'skip', 'police', 'trouble', 'liquor', 'plentiful', 'cost', 'arrabiata']
# bluestone-lane-hoboken_processed.csv
# ['wife', 'past', 'heat', 'worked', 'expect', 'jersey', 'type', 'relaxing', 'dined']
# bwè-kafe-hoboken_processed.csv
# ['party', 'rib', 'little', 'still', 'two', 'want', 'taste', 'always', 'amazing']
# cafe-michelina-hoboken_processed.csv
# ['town', 'regular', 'container', 'bring', 'came', 'liked', 'far', 'muffin', 'bite']
# cafe-vista-hoboken-2_processed.csv
# ['ca', 'first', 'fruit', 'business', 'around', 'sure', 'sure', 'mimosa', 'right']
# carlos-bakery-hoboken-9_processed.csv
# ['got', 'rare', 'thing', 'money', 'need', 'overall', 'though', 'recommend', 'mussel']
# carpe-diem-pub-and-restaurant-hoboken-2_processed.csv
# ['booked', 'vinegar', 'replaced', 'happening', 'cooked', 'poorly', 'familiar', 'moving', 'care']
# chango-kitchen-hoboken_processed.csv
# ['tonight', 'certainly', 'sadly', 'disrespectful', 'completely', 'eaten', 'fat', 'heart', 'available']
# chicken-factory-hoboken-2_processed.csv
# ['take', 'disappointing', 'real', 'whole', 'couple', 'trying', 'soggy', 'to', 'friday']
# choc-o-pain-hoboken-9_processed.csv
# ['dip', 'stay', 'suggest', 'super', 'class', 'hungry', 'tzatziki', 'sort', 'delish']
# city-bistro-hoboken_processed.csv
# ['2000s', 'yasuda', 'foggy', 'curve', 'loving', 'triple', 'becomes', 'instagrammable', 'explore']
# city-of-saints-coffee-roasters-hoboken_processed.csv
# ['band', 'recommend', 'large', 'closed', 'grocery', 'chip', 'muzz', 'run', 'almost']
# corkscrew-bar-jersey-city_processed.csv
# ['speak', 'joke', 'tonkatsu', 'understanding', 'brand', 'worked', 'succulent', 'change', 'broth']
# court-street-restaurant-and-bar-hoboken_processed.csv
# ['terrible', 'men', 'tropic', 'fighting', 'biden', 'wack', 'treated', 'hearing', 'curiosity']
# cucina-saporito-hoboken_processed.csv
# ['calmer', 'yall', 'wet', 'bummed', 'gladly', 'ignore', 'feb', 'overlooking', 'feedback']
# curry-up-now-hoboken_processed.csv
# ['outdoor', 'bbq', 'beef', 'horrible', 'give', 'went', 'amazing', 'right', 'parm']
# del-friscos-grille-hoboken_processed.csv
# ['airbnb', 'crusted', 'tri', 'justified', 'with', 'coveted', 'solicitous', 'restricted', '120']
# dino-and-harrys-steak-house-hoboken-5_processed.csv
# ['singing', 'double', 'positive', 'poured', 'born', 'nightmare', 'component', 'sesame', 'school']
# dolce-and-salato-hoboken_processed.csv
# ['pitcher', 'high', 'serve', 'group', 'customer', 'wish', 'da', 'far', 'beef']
# doms-bakery-grand-hoboken_processed.csv
# ['area', 'shrimp', 'time', 'two', 'little', 'two', 'garlic', 'make', 'friend']
# dozzino-hoboken_processed.csv
# ['fast', 'oily', 'double', 'post', 'beyond', 'list', 'friend', 'caffeine', 'intimate']
# ds-soul-full-cafe-hoboken_processed.csv
# ['daughter', 'giving', 'purple', 'hear', 'exactly', 'round', 'opinion', 'buttery', 'gluten']
# east-la-hoboken_processed.csv
# ['cool', 'give', 'hoboken', 'ever', 'love', 'front', 'portion', 'avocado', 'vodka']
# elysian-cafe-hoboken_processed.csv
# ['watch', 'lot', 'give', 'meal', 'always', 'ok', 'give', 'line', 'grilled']
# empire-coffee-and-tea-company-hoboken_processed.csv
# ['keeping', 'rush', 'sliced', 'pain', 'fold', 'sam', 'rubbery', 'over', 'prior']
# empyrean-indian-kitchen-and-bar-hoboken-2_processed.csv
# ['enjoying', 'yummy', 'rich', 'dont', 'tiny', 'certainly', 'basically', 'bitter', 'literally']
# finnegans-pub-hoboken-2_processed.csv
# ['work', 'choice', 'smoothie', 'awful', 'baked', 'mean', 'authentic', 'espresso', 'way']
# fiore-deli-of-hoboken-hoboken_processed.csv
# ['loaded', 'cali', 'appetizer', 'asap', 'snack', 'routine', 'plank', 'fell', 'earthy']
# frank-sinatra-park-hoboken_processed.csv
# ['give', 'happy', 'onion', 'found', 'pick', 'type', 'buffet', 'helpful', 'gave']
# gfg-bakery-cafe-hoboken_processed.csv
# ['true', 'mess', 'packet', 'disgusted', 'truly', 'onion', 'cheap', 'left', 'yes']
# giovannis-pizzeria-and-restaurant-hoboken-6_processed.csv
# ['adorable', 'practically', 'truly', 'class', 'airy', 'soggy', 'ka', 'expand', 'sold']
# gogi-grill-hoboken-hoboken-2_processed.csv
# ['dont', 'awhile', 'ago', 'middle', 'covid', 'dim', 'bet', 'upon', 'coconut']
# gong-cha-hoboken_processed.csv
# ['remember', 'real', 'fu', 'boyfriend', 'expected', 'everywhere', 'remember', 'plain', 'recommended']
# grand-vin-hoboken_processed.csv
# ['spilling', 'wandering', 'ohhhhhh', 'jc', 'reevaluate', 'downside', 'ver', 'hopping', 'eww']
# greektown-hoboken-3_processed.csv
# ['upstairs', 'eel', 'cooked', 'past', 'saw', 'whole', 'fiores', 'limited', 'ricotta']
# green-pear-cafe-hoboken_processed.csv
# ['dip', 'stay', 'suggest', 'super', 'class', 'hungry', 'tzatziki', 'sort', 'delish']
# green-rock-tap-and-grill-hoboken_processed.csv
# ['due', 'soy', 'except', 'properly', 'double', 'chain', 'entire', '05', 'expecting']
# grimaldis-hoboken_processed.csv
# ['flexible', 'buttery', 'hopefully', 'forget', 'warmed', 'finished', '1st', 'soooo', 'garnish']
# grubbs-take-away-hoboken_processed.csv
# ['return', 'ever', 'quite', 'couple', 'hype', 'problem', 'salty', 'glad', 'ate']
# halifax-hoboken-2_processed.csv
# ['really', 'lunch', 'sauce', 'customer', 'bakery', 'get', 'ordered', 'little', 'meal']
# happy-vegans-hoboken-2_processed.csv
# ['bit', 'appetizer', 'banana', 'night', 'find', 'packed', 'probably', 'ca', 'excellent']
# hidden-grounds-coffee-hoboken-4_processed.csv
# ['try', 'nice', 'spot', 'arrived', 'cookie', 'still', 'pretty', 'food', 'first']
# hidden-grounds-coffee-hoboken-6_processed.csv
# ['fact', 'may', 'might', 'shot', 'bigger', 'ended', 'chon', 'excited', 'cacio']
# hoboken-hot-bagels-hoboken_processed.csv
# ['advance', 'macaroni', 'recommended', 'apartment', 'using', 'throw', 'gobi', 'lover', 'disappoint']
# honeygrow-hoboken_processed.csv
# ['prepping', 'rapid', 'vero', 'lipstick', 'midst', 'caliber', 'visible', 'breathe', 'kababs']
# house-of-que-hoboken-2_processed.csv
# ['double', 'mentioned', 'thumb', 'perhaps', 'majority', 'compared', 'smelled', 'hipster', 'lava']
# hudson-river-waterfront-walkway-hoboken_processed.csv
# ['make', 'much', 'tasty', 'going', 'oven', 'star', 'spicy', 'drink', 'meatball']
# il-tavolo-di-palmisano-hoboken-2_processed.csv
# ['older', 'drop', 'picture', 'professional', 'saving', 'write', 'melted', 'woman', 'law']
# illuzion-hoboken_processed.csv
# ['appreciated', 'tartar', 'avocado', 'responded', 'chance', 'appropriate', 'test', 'perfection', 'romantic']
# insomnia-cookies-hoboken_processed.csv
# ['get', 'fish', 'really', 'came', 'crust', 'come', 'mutz', 'one', 'entree']
# jeffersons-coffee-hoboken-6_processed.csv
# ['star', 'either', 'fast', 'price', 'nj', 'although', 'service', 'wish', 'waitress']
# jeffersons-coffee-hoboken_processed.csv
# ['offer', 'stick', 'enjoyed', 'finished', 'tomato', 'complaint', 'note', 'orange', 'fine']
# joboken-cafe-hoboken-2_processed.csv
# ['nice', 'like', 'food', 'place', 'hoboken', 'one', 'google', 'sandwich', 'good']
# johnny-pepperoni-hoboken_processed.csv
# ['zack', 'in', 'strong', 'usually', 'filled', 'trader', 'per', 'pre', 'simple']
# jps-bagel-express-hoboken_processed.csv
# ['little', 'hoboken', 'meat', 'long', 'still', 'many', 'paneer', 'lunch', 'byob']
# juns-macaron-gelato-hoboken_processed.csv
# ['inside', 'large', 'opened', 'okay', 'money', 'full', 'tom', 'rose', 'visit']
# karma-kafe-hoboken_processed.csv
# ['la', 'italiani', 'ladyabi', 'suffered', 'once', 'tow', 'brocolli', 'dispenser', 'tempered']
# keming-restaurant-hoboken-2_processed.csv
# ['gem', 'person', 'picky', 'buy', 'lover', 'venue', 'hearty', 'fun', 'beyond']
# kung-fu-tea-hoboken_processed.csv
# ['separate', 'parking', 'dont', 'bothered', 'house', 'rate', 'except', 'month', 'quality']
# la-bouche-hoboken-3_processed.csv
# ['scarce', 'dive', 'spam', 'exaggeration', 'opportunity', 'restuarant', 'albeit', 'cornbread', 'boring']
# la-casa-hoboken_processed.csv
# ['bro', 'apartment', 'alone', 'lied', 'mother', 'neighborhood', '65', 'fare', 'valley']
# la-isla-restaurant-hoboken_processed.csv
# ['bull', 'put', 'lemonade', 'keep', 'case', 'return', 'biancamano', 'review', 'item']
# la-isla-restaurant-uptown-hoboken_processed.csv
# ['scotch', 'condiment', 'comparable', 'meant', 'spectacular', 'orange', 'certain', 'break', 'flavored']
# leos-grandevous-hoboken_processed.csv
# ['dueling', 'worst', 'kinda', 'morning', 'frozen', 'pro', 'bone', 'topped', 'empty']
# lisas-italian-deli-hoboken_processed.csv
# ['pretty', 'fresh', 'tried', 'waitress', 'also', 'around', 'try', 'seating', 'try']
# lo-fatt-chow-hoboken_processed.csv
# ['husband', 'excellent', 'seems', 'birthday', 'world', 'distancing', 'compare', 'spread', 'baked']
# lolas-hoboken_processed.csv
# ['friendly', 'chicken', 'soup', 'took', 'thing', 'well', 'get', 'shop', 'well']
# losurdos-italian-bakery-and-deli-hoboken_processed.csv
# ['went', 'onion', 'great', 'experience', 'much', 'even', 'best', 'definitely', 'shrimp']
# louise-and-jerrys-hoboken_processed.csv
# ['believe', 'container', 'smooth', 'security', 'service', 'section', 'competition', 'kid', 'fell']
# luca-brasis-deli-hoboken-151_processed.csv
# ['bin14', 'connoisseur', 'overwhelmed', 'indication', 'cracked', 'reviewed', 'class', 'bc', 'semolina']
# m-and-p-biancamano-hoboken_processed.csv
# ['whatever', 'sadly', 'hainanese', 'stop', 'grew', 'cost', 'whatever', 'paper', 'arancini']
# madd-hatter-hoboken-3_processed.csv
# ['mediocre', 'lean', 'remember', 'grabbed', 'arugula', 'buddy', 'hoping', 'balance', 'extensive']
# malibu-diner-hoboken_processed.csv
# ['delicious', 'avocado', 'salad', '15', 'right', 'see', 'much', 'bacon', 'main']
# mamouns-falafel-hoboken-hoboken-2_processed.csv
# ['cent', 'flavored', 'count', 'remind', '5th', 'frites', 'explosion', 'faced', 'gorgonzola']
# mango-mango-hoboken_processed.csv
# ['part', 'away', 'fun', 'oh', 'icing', 'club', 'entree', 'might', 'price']
# margheritas-hoboken_processed.csv
# ['clearing', 'tnt', 'overtook', 'fish', 'concrete', 'strategy', 'stelle', 'harsh', 'merguez']
# marios-classic-pizza-hoboken_processed.csv
# ['snack', 'serve', 'belly', '14', 'cardboard', 'basically', 'trip', 'needed', 'terrific']
# mcswiggans-pub-hoboken_processed.csv
# ['enjoy', 'since', 'protein', 'seated', 'ca', 'said', 'perfect', 'even', 'next']
# midtown-philly-steaks-hoboken-2_processed.csv
# ['return', 'ever', 'quite', 'couple', 'hype', 'problem', 'salty', 'glad', 'ate']
# mikie-squared-bar-and-grill-hoboken_processed.csv
# ['fare', 'added', 'reason', 'dropped', 'basically', 'cover', 'soooo', 'press', 'getting']
# mojo-coffee-company-hoboken_processed.csv
# ['especially', 'best', 'peanut', 'around', 'bit', 'party', 'cut', 'much', 'top']
# monroes-hoboken_processed.csv
# ['soon', 'seemed', 'chocolate', 'different', 'without', 'tried', 'quickly', 'yet', 'dip']
# morans-hoboken_processed.csv
# ['prepared', 'figured', '16', 'till', 'missing', 'relatively', 'hold', 'mixed', 'braised']
# mr-wraps-hoboken_processed.csv
# ['game', 'better', 'tasted', 'say', 'fresh', 'however', 'make', 'pastry', 'perfect']
# mulligans-hoboken_processed.csv
# ['never', 'wanted', 'street', 'thought', 'overpriced', 'expect', 'average', 'solid', 'room']
# muteki-ramen-hoboken_processed.csv
# ['chill', 'plate', 'dessert', 'though', 'different', 'move', 'lettuce', 'waffle', 'however']
# napolis-pizza-hoboken-2_processed.csv
# ['kane', 'forgettable', 'flexible', 'argued', 'practically', 'variety', 'voted', 'genuine', 'haha']
# napolis-pizza-hoboken_processed.csv
# ['shuffleboard', 'count', 'dinner', 'debit', 'absolute', 'saved', 'finished', 'depending', 'moving']
# northern-soul-kitchen-and-bar-hoboken_processed.csv
# ['tasting', 'consider', 'bf', 'patiently', 'decide', 'curly', 'john', 'care', 'prosecco']
# o-bagel-hoboken_processed.csv
# ['hour', 'order', 'sweet', 'like', 'way', 'much', 'indian', 'friendly', 'table']
# okinawa-sushi-and-grill-hoboken-2_processed.csv
# ['culture', 'tblt', 'diplomatically', 'shockingly', 'designed', 'snagged', 'break', 'gina', 'ultra']
# old-german-bakery-hoboken_processed.csv
# ['presented', 'establishment', 'sooooo', 'condescending', 'lower', 'happens', 'relatively', 'heavenly', 'spritz']
# onieals-hoboken_processed.csv
# ['yeah', 'docked', 'cereal', 'curt', 'ridgewood', 'complemented', 'sod', 'ie', 'briny']
# orale-mexican-kitchen-hoboken_processed.csv
# ['award', 'rhythm', 'sayin', 'intended', 'outrageous', 'marbled', 'barley', 'color', 'margheritas']
# otto-strada-hoboken-3_processed.csv
# ['5pm', 'coke', 'none', 'essentially', 'cant', 'appreciated', 'kitchen', 'sounded', 'requested']
# panello-hoboken_processed.csv
# ['bit', 'appetizer', 'banana', 'night', 'find', 'packed', 'probably', 'ca', 'excellent']
# panera-bread-hoboken_processed.csv
# ['relax', 'honest', 'health', 'piece', 'husband', 'split', 'bonchon', 'incredibly', 'everyone']
# pastrami-house-hoboken_processed.csv
# ['fantastic', 'maybe', 'asian', 'much', 'life', 'black', 'eating', 'space', 'star']
# pho-nomenon-noodle-and-grill-hoboken_processed.csv
# ['fare', 'added', 'reason', 'dropped', 'basically', 'cover', 'soooo', 'press', 'getting']
# piccolos-cheesesteaks-hoboken-hoboken_processed.csv
# ['board', 'eaten', 'flavour', 'simple', 'cup', 'add', 'wo', 'world', 'sunday']
# pico-taco-hoboken-2_processed.csv
# ['fare', 'added', 'reason', 'dropped', 'basically', 'cover', 'soooo', 'press', 'getting']
# pier-a-park-hoboken_processed.csv
# ['sit', 'everything', 'ordering', 'sat', 'though', 'space', 'cheesesteaks', 'location', 'thing']
# pier-c-hoboken_processed.csv
# ['live', 'though', 'back', 'worst', 'sure', 'look', 'lisa', 'made', 'waiter']
# piki-poké-hoboken-2_processed.csv
# ['park', 'salty', 'must', 'return', 'johnny', 'kinda', 'para', 'plenty', 'return']
# pilsener-haus-and-biergarten-hoboken_processed.csv
# ['sought', 'clogging', 'biscuit', 'pleased', 'carol', 'returned', 'astonishing', 'barrel', 'zuchinni']
# pizza-republic-hoboken_processed.csv
# ['ufc', 'avg', 'step', 'discovered', 'relationship', 'flag', 'dare', 'completely', 'hopefully']
# precious-japanese-and-chinese-cuisine-hoboken_processed.csv
# ['organized', 'considerably', 'thicc', 'unwanted', 'sick', 'sanitary', 'smith', 'relaxed', 'figure']
# purely-juiced-hoboken_processed.csv
# ['good', 'sushi', 'like', 'service', 'good', 'would', 'thai', 'place', 'pasta']
# quality-greens-kitchen-hoboken_processed.csv
# ['zack', 'in', 'strong', 'usually', 'filled', 'trader', 'per', 'pre', 'simple']
# ritas-italian-ice-hoboken_processed.csv
# ['scene', 'egg', 'extremely', 'missing', 'either', 'together', 'getting', 'either', 'three']
# robongi-hoboken_processed.csv
# ['outgoing', 'celery', 'flaky', 'ripping', 'crispiness', 'shio', 'ottima', 'deciding', 'lower']
# rosticeria-da-gigi-hoboken_processed.csv
# ['fresh', 'crumb', 'entirely', 'include', 'wont', 'purse', 'reliable', 'luke', 'kiss']
# saku-hoboken-2_processed.csv
# ['shall', 'cinco', 'vibrant', 'madison', 'staying', 'thinking', 'third', 'equally', 'brass']
# san-giuseppe-hoboken_processed.csv
# ['reserved', 'worthy', 'wafer', 'highly', 'description', 'sox', 'enjoys', 'ac', 'takeout']
# satay-malaysian-cuisine-hoboken-2_processed.csv
# ['train', 'pick', 'version', 'single', 'employee', 'head', 'bon', 'ordering', 'lovely']
# seven-valleys-hoboken_processed.csv
# ['definite', 'hill', 'downside', 'detail', 'calzones', 'mentioned', 'detour', 'umbrella', 'reasonably']
# shaka-bowl-hoboken-2_processed.csv
# ['ambiance', 'pork', 'burrito', 'extremely', 'ingredient', 'away', 'extra', 'every', 'large']
# shaka-bowl-hoboken_processed.csv
# ['ahead', 'rye', 'fatt', 'margarita', 'domino', 'aspect', 'cooking', 'vegan', 'homey']
# shokudo-hoboken_processed.csv
# ['moved', 'opted', 'bang', 'napkin', 'walkway', 'minute', 'plan', 'au', 'antipasto']
# shoprite-of-hoboken-hoboken_processed.csv
# ['calamari', 'show', 'per', 'insisted', 'somehow', 'ago', 'expired', 'heat', 'walk']
# sirenetta-seafood-and-raw-bar-hoboken_processed.csv
# ['dinner', 'also', 'fried', 'could', 'try', 'thing', 'place', 'like', 'bread']
# sorellina-hoboken_processed.csv
# ['bummed', 'dishwasher', 'knocked', 'doused', 'method', 'namesake', 'temporarily', 'shocked', 'tastiest']
# south-lions-hoboken-2_processed.csv
# ['kind', 'done', 'came', 'girl', 'perfect', 'man', 'sri', 'enough', 'know']
# south-street-fish-and-ramen-co-hoboken_processed.csv
# ['nacho', 'mignon', 'looking', 'outside', 'thank', 'change', 'falafel', 'fruit', 'week']
# sri-thai-thai-restaurant-hoboken_processed.csv
# ['grabbed', 'figure', 'pressed', 'gon', 'aside', 'forgot', 'happier', 'casual', 'cesar']
# stingray-lounge-uptown-hoboken-2_processed.csv
# ['classic', 'sick', 'muteki', 'stand', 'purchase', 'shit', 'ole', 'took', 'honestly']
# sushi-lounge-hoboken_processed.csv
# ['limit', 'pure', 'wonder', 'insulted', 'starve', 'buttermilk', 'wrapper', 'lid', '45pm']
# sweet-hoboken_processed.csv
# ['proper', 'solidly', 'florist', 'sangria', 'led', 'gay', 'rendered', 'covering', 'thereafter']
# t-thai-hoboken_processed.csv
# ['phillies', 'afford', 'machine', 'warned', 'wee', 'mixer', 'drizzling', 'excuse', 'encrusted']
# tenth-street-pasta-and-pizza-hoboken_processed.csv
# ['guaranteed', 'sell', 'plentiful', 'napoli', 'choc', 'ranger', 'living', 'unlike', 'include']
# texas-arizona-hoboken_processed.csv
# ['older', 'drop', 'picture', 'professional', 'saving', 'write', 'melted', 'woman', 'law']
# the-ale-house-hoboken-2_processed.csv
# ['awesome', 'cooked', 'go', 'server', 'got', 'room', 'la', 'staff', 'nice']
# the-brass-rail-hoboken-hoboken_processed.csv
# ['bon', 'redeeming', 'culinary', 'vomited', 'est', 'dealt', 'fiona', 'lambrusco', 'definition']
# the-brick-fire-baked-pizza-hoboken-3_processed.csv
# ['que', 'making', 'melted', 'fair', 'broke', 'im', 'festival', 'sidewalk', 'fully']
# the-cuban-restaurant-and-bar-hoboken-2_processed.csv
# ['wednesday', 'anything', 'added', 'dinner', 'cold', 'eating', 'stick', 'stopped', 'think']
# the-hive-hoboken_processed.csv
# ['thursday', 'corn', 'authentic', 'pick', 'bread', 'cool', 'tender', 'salmon', 'share']
# the-little-grocery-hoboken-3_processed.csv
# ['fare', 'added', 'reason', 'dropped', 'basically', 'cover', 'soooo', 'press', 'getting']
# the-madison-bar-and-grill-hoboken_processed.csv
# ['180', 'sunset', 'headphone', 'tater', 'puppy', 'sane', 'guarantee', '95', 'hospitality']
# the-roost-outpost-hoboken-3_processed.csv
# ['star', 'either', 'fast', 'price', 'nj', 'although', 'service', 'wish', 'waitress']
# the-shepherd-and-the-knucklehead-of-hoboken-hoboken-2_processed.csv
# ['show', 'miss', 'in', 'dessert', 'buying', 'soon', 'monday', 'across', 'eaten']
# the-stewed-cow-hoboken_processed.csv
# ['trip', 'noticed', 'pearl', 'encountered', '1st', 'fault', 'mexican', 'heaven', 'personal']
# thomas-ice-cream-cafe-hoboken-2_processed.csv
# ['ca', 'first', 'fruit', 'business', 'around', 'sure', 'sure', 'mimosa', 'right']
# tony-boloneys-hoboken-hoboken_processed.csv
# ['fave', 'horn', 'updated', 'de', 'becomes', '200', 'pnc', 'raven', 'boniato']
# tornas-pizzeria-hoboken_processed.csv
# ['15', 'brought', 'rangoon', 'specifically', 'impressed', 'mom', 'update', 'including', 'forgot']
# tosti-cafe-and-kitchen-hoboken_processed.csv
# ['young', 'wing', 'sum', 'course', 'instead', 'sign', 'couple', 'crepe', 'beautiful']
# touch-the-heart-hoboken_processed.csv
# ['money', 'romaine', 'picked', 'box', 'comparison', 'southern', 'lucky', 'signature', 'ton']
# turning-point-of-hoboken-hoboken_processed.csv
# ['wednesday', 'anything', 'added', 'dinner', 'cold', 'eating', 'stick', 'stopped', 'think']
# ubu-hoboken_processed.csv
# ['return', 'ever', 'quite', 'couple', 'hype', 'problem', 'salty', 'glad', 'ate']
# union-hall-hoboken_processed.csv
# ['lighting', 'month', 'packaged', 'chef', 'boy', 'grab', 'mayo', 'expect', 'upon']
# urban-coalhouse-pizza-bar-hoboken-4_processed.csv
# ['worth', 'make', 'mix', 'literally', 'square', 'yes', 'amount', 'enjoy', 'evening']
# vitos-italian-deli-hoboken_processed.csv
# ['juicy', 'orderd', 'suprema', 'construction', 'leisure', 'hence', 'iffy', 'blessed', 'sticker']
# vivi-bubble-tea-hoboken_processed.csv
# ['varying', 'attack', 'reminiscent', '4pm', 'angela', 'madd', 'individually', 'resist', 'gentleman']
# wicked-wolf-tavern-hoboken_processed.csv
# ['understaffed', 'worcestershire', 'originality', 'tourist', 'razza', 'odor', 'thrown', 'bianco', 'cafeteria']
# willie-mcbrides-hoboken_processed.csv
# ['give', 'happy', 'onion', 'found', 'pick', 'type', 'buffet', 'helpful', 'gave']
# yeung-ii-sushi-asian-cuisine-hoboken-61_processed.csv
# ['impressive', 'lazy', 'kebob', 'tuesday', 'planet', 'anybody', 'calorie', 'bomb', 'splitting']
# yukis-coffee-and-bakery-hoboken_processed.csv
# ['especially', 'best', 'peanut', 'around', 'bit', 'party', 'cut', 'much', 'top']
# zacks-oak-bar-and-restaurant-hoboken_processed.csv
# ['neighborhood', 'take', 'salty', 'fine', 'block', 'bouncer', 'never', 'see', 'rigatoni']
# zero-otto-uno-cafe-hoboken_processed.csv
# ['spacious', 'recently', 'zucchini', 'ran', 'feeling', 'somewhat', 'potato', 'mix', 'might']
